# %% [markdown]
# <a href="https://colab.research.google.com/github/sonjoy1s/ML/blob/main/Seabron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
student = pd.read_csv('/content/sns_data (1).csv')
student.head()
# Out:
#    student_id class_level   subject  study_hours  test_score  week  \
# 0           1    Freshman      Math            5          78     1
# 1           2    Freshman   Science            3          65     1
# 2           3    Freshman   History            4          70     1
# 3           4    Freshman  Language            2          60     1
# 4           5   Sophomore      Math            6          82     1
#
#    attendance_rate  gender  hostel  Tshirt_size
# 0               90    Male    True           30
# 1               80  Female   False           20
# 2               85    Male    True           20
# 3               75  Female    True           40
# 4               92    Male    True           20

# %%
sns.lineplot(data=student, x='week',y='attendance_rate',errorbar=None,hue='gender')
# Out:
# <Axes: xlabel='week', ylabel='attendance_rate'>

# %%
sns.relplot(kind='line',data=student, x='week',y='attendance_rate',errorbar=None,hue='gender')

# %%
sns.scatterplot(data=student, x='study_hours',y='test_score',hue='gender',style='subject')
# Out:
# <Axes: xlabel='study_hours', ylabel='test_score'>

# %%
sns.relplot(kind='scatter',data=student, x='study_hours',y='test_score',hue='gender',style='subject')

# %%
tips_data = sns.load_dataset('tips')
tips_data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(kind='scatter',data=tips_data, x='total_bill',y='tip',hue='sex',style='time',size='size')

# %%
df = pd.read_csv('/content/student_dataset_complete.csv')
df
# Out:
#     number_courses  time_study   Marks  student_id  class_level  subject  \
# 0                3       4.508  19.202           1           10  Science
# 1                4       0.096   7.734           2           12     Math
# 2                4       3.133  13.811           3           11  Science
# 3                6       7.909  53.018           4           10  Science
# 4                8       7.811  55.299           5           11  English
# ..             ...         ...     ...         ...          ...      ...
# 95               6       3.561  19.128          96           11  English
# 96               3       0.301   5.609          97           10  Science
# 97               4       7.163  41.444          98           11     Math
# 98               7       0.309  12.027          99           12     Math
# 99               3       6.335  32.357         100           12  Science
#
#     study_hours  test_score  week  attendance_rate gender  hostel  \
# ...

# %% [markdown]
# # Facet plot

# %%
sns.scatterplot(data=df, x='study_hours',y='Marks',hue='gender',style='subject')
# Out:
# <Axes: xlabel='study_hours', ylabel='Marks'>

# %%
sns.relplot(kind='scatter',data=df, x='study_hours',y='Marks',hue='gender',style='subject')

# %%
sns.relplot(kind='scatter',data=df, x='study_hours',y='test_score',col='gender',row='hostel')

# %%
sns.relplot(kind='scatter',data=df, x='study_hours',y='test_score',col='week',col_wrap=2)

# %% [markdown]
# # histrogram

# %%
sns.histplot(data=df,x='attendance_rate',hue='gender',bins=10,element='step')
# Out:
# <Axes: xlabel='attendance_rate', ylabel='Count'>

# %%
sns.displot(kind='hist',data=df,x='attendance_rate')

# %%
sns.displot(kind='hist',data=df,x='attendance_rate',col='gender')

# %%
sns.displot(kind='hist',data=df,x='study_hours',col='gender')

# %% [markdown]
# # KDE plot Seabron

# %%
tips_data = sns.load_dataset('tips')
tips_data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.kdeplot(data=df,x='attendance_rate',hue='gender')
# Out:
# <Axes: xlabel='attendance_rate', ylabel='Density'>

# %%
student
# Out:
#     student_id class_level   subject  study_hours  test_score  week  \
# 0            1    Freshman      Math            5          78     1
# 1            2    Freshman   Science            3          65     1
# 2            3    Freshman   History            4          70     1
# 3            4    Freshman  Language            2          60     1
# 4            5   Sophomore      Math            6          82     1
# ..         ...         ...       ...          ...         ...   ...
# 90          91      Junior      Math            7          85     6
# 91          92      Junior   Science            6          78     6
# 92          93      Junior   History            5          72     6
# 93          94      Junior  Language            4          68     6
# 94          95      Senior      Math            6          84     6
#
#     attendance_rate  gender  hostel  Tshirt_size
# 0                90    Male    True           30
# 1                80  Female   False           20
# ...

# %%
sns.countplot(data=student,x='gender')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(data=student,x='subject',hue='gender')
# Out:
# <Axes: xlabel='subject', ylabel='count'>

# %%
sns.barplot(data=student,x='gender',y='test_score',errorbar=None,estimator=np.median)
# Out:
# <Axes: xlabel='gender', ylabel='test_score'>

# %% [markdown]
# #pairplot and join plot

# %%
student
# Out:
#     student_id class_level   subject  study_hours  test_score  week  \
# 0            1    Freshman      Math            5          78     1
# 1            2    Freshman   Science            3          65     1
# 2            3    Freshman   History            4          70     1
# 3            4    Freshman  Language            2          60     1
# 4            5   Sophomore      Math            6          82     1
# ..         ...         ...       ...          ...         ...   ...
# 90          91      Junior      Math            7          85     6
# 91          92      Junior   Science            6          78     6
# 92          93      Junior   History            5          72     6
# 93          94      Junior  Language            4          68     6
# 94          95      Senior      Math            6          84     6
#
#     attendance_rate  gender  hostel  Tshirt_size
# 0                90    Male    True           30
# 1                80  Female   False           20
# ...

# %%
marks_s = student[['study_hours','test_score','week','attendance_rate']]

# %%
sns.pairplot(data=marks_s)

# %%
# joint plot
sns.jointplot(data=marks_s,x='study_hours',y='test_score')

# %%
#plotly sclatter plot
fig = px.scatter(student,x='study_hours',y='test_score')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
enrollment = pd.read_csv('/content/enrollment_data.csv')
enrollment
# Out:
#    Year  Programming  Digital Marketing
# 0  2015          589                734
# 1  2016          862                963
# 2  2017         1085               1157
# 3  2018         1150               1404
# 4  2019         1439               1497
# 5  2020         1715               1579
# 6  2021         1785               1948
# 7  2022         1995               2073
# 8  2023         2236               2310
# 9  2024         2442               2338

# %%
fig=px.line(enrollment,x='Year',y='Programming')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.line(enrollment,x='Year',y='Digital Marketing',markers='o')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_html('Digital Marketing.html')
