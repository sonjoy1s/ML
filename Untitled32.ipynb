# %% [markdown]
# <a href="https://colab.research.google.com/github/sonjoy1s/ML/blob/main/Untitled32.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('/content/nobel_prizes_1901-2025_cleaned.csv')
df
# Out:
#      award_year date_awarded  prize_amount  prize_amount_adjusted  \
# 0          1901   11/12/1901        150782               10833458
# 1          1901   11/14/1901        150782               10833458
# 2          1901   12/10/1901        150782               10833458
# 3          1901   12/10/1901        150782               10833458
# 4          1901   11/12/1901        150782               10833458
# ..          ...          ...           ...                    ...
# 990        2025    10/7/2025      11000000               11000000
# 991        2025    10/6/2025      11000000               11000000
# 992        2025   10/13/2025      11000000               11000000
# 993        2025    10/9/2025      11000000               11000000
# 994        2025    10/6/2025      11000000               11000000
#
#      laureate_id              known_name                     full_name   sex  \
# 0          160.0  Jacobus H. van 't Hoff  Jacobus Henricus van 't Hoff  male
# ...

# %%
df.shape
# Out:
# (995, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   award_year             995 non-null    int64
#  1   date_awarded           995 non-null    object
#  2   prize_amount           995 non-null    int64
#  3   prize_amount_adjusted  995 non-null    int64
#  4   laureate_id            995 non-null    float64
#  5   known_name             995 non-null    object
#  6   full_name              995 non-null    object
#  7   sex                    752 non-null    object
#  8   portion                995 non-null    float64
#  9   sort_order             995 non-null    float64
#  10  motivation             995 non-null    object
#  11  category               995 non-null    object
#  12  birth_date             752 non-null    object
#  13  birth_city             750 non-null    object
# ...

# %%
df.describe(include='all')
# Out:
#          award_year date_awarded  prize_amount  prize_amount_adjusted  \
# count    995.000000          995  9.950000e+02           9.950000e+02
# unique          NaN          470           NaN                    NaN
# top             NaN   11/14/1946           NaN                    NaN
# freq            NaN            7           NaN                    NaN
# mean    1974.826131          NaN  3.959410e+06           8.030975e+06
# std       35.009814          NaN  4.275932e+06           4.101196e+06
# min     1901.000000          NaN  1.149350e+05           3.006134e+06
# 25%     1950.000000          NaN  1.727600e+05           3.923237e+06
# 50%     1980.000000          NaN  8.800000e+05           6.845037e+06
# 75%     2004.000000          NaN  9.000000e+06           1.160359e+07
# max     2025.000000          NaN  1.100000e+07           1.554754e+07
#
#         laureate_id        known_name         full_name   sex     portion  \
# ...

# %%
df.nunique()
# Out:
# award_year               122
# date_awarded             470
# prize_amount              99
# prize_amount_adjusted    120
# laureate_id              990
# known_name               990
# full_name                990
# sex                        2
# portion                    4
# sort_order                 3
# motivation               683
# category                   6
# birth_date               737
# birth_city               526
# birth_country             76
# birth_latitude           509
# birth_longitude          509
# death_date               552
# death_city               280
# death_country             47
# death_latitude           266
# death_longitude          266
# affiliation_name         266
# affiliation_city         165
# affiliation_country       28
# affiliation_latitude     160
# affiliation_longitude    160
# wikipedia_url            747
# is_shared                  2
# winners_per_year          14
# winners_per_category       6
# is_repeat_winner           2
# ...

# %%
df.isnull().sum()
# Out:
# award_year                 0
# date_awarded               0
# prize_amount               0
# prize_amount_adjusted      0
# laureate_id                0
# known_name                 0
# full_name                  0
# sex                      243
# portion                    0
# sort_order                 0
# motivation                 0
# category                   0
# birth_date               243
# birth_city               245
# birth_country            244
# birth_latitude           261
# birth_longitude          261
# death_date               432
# death_city               447
# death_country            441
# death_latitude           461
# death_longitude          461
# affiliation_name         442
# affiliation_city         444
# affiliation_country      442
# affiliation_latitude     453
# affiliation_longitude    453
# wikipedia_url            243
# is_shared                  0
# winners_per_year           0
# winners_per_category       0
# is_repeat_winner           0
# ...

# %%
terget_col ='winners_per_category'
plt.figure(figsize=(10,6))
df[terget_col].value_counts().sort_index().plot(kind='bar',color=['lightcoral','lightgreen'])
plt.xlabel('winners_per_category')
plt.ylabel('count')
plt.title('winners_per_category')
plt.show()
