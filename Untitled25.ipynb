# %% [markdown]
# <a href="https://colab.research.google.com/github/sonjoy1s/ML/blob/main/Untitled25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO
data = """EmployeeID,EmployeeName,Age,Salary,Price,Marks1,Marks2,Marks3
E101,Alice,25,50000,1200,85,90,88
E102,Bob,30,60000,1500,78,82,80
E103,Charlie,22,52000,1100,92,95,90
E101,Alice,25,50000,1200,85,90,88
E104,David,45,80000,2500,88,85,89
E105,Eve,29,58000,1300,76,79,81
E106,Frank,,2200,90,91,92,77
E107,Grace,34,1900,81,83,80
E108,Heidi,38,1800,84,86,88
E109,Ivan,26,53000,1400,95,92,94
E102,Bob,30,60000,1500,78,82,80"""

df = pd.read_csv(StringIO(data))
df
# Out:
#    EmployeeID EmployeeName   Age  Salary  Price  Marks1  Marks2  Marks3
# 0        E101        Alice  25.0   50000   1200      85      90    88.0
# 1        E102          Bob  30.0   60000   1500      78      82    80.0
# 2        E103      Charlie  22.0   52000   1100      92      95    90.0
# 3        E101        Alice  25.0   50000   1200      85      90    88.0
# 4        E104        David  45.0   80000   2500      88      85    89.0
# 5        E105          Eve  29.0   58000   1300      76      79    81.0
# 6        E106        Frank   NaN    2200     90      91      92    77.0
# 7        E107        Grace  34.0    1900     81      83      80     NaN
# 8        E108        Heidi  38.0    1800     84      86      88     NaN
# 9        E109         Ivan  26.0   53000   1400      95      92    94.0
# 10       E102          Bob  30.0   60000   1500      78      82    80.0

# %%
df['Discount_Price']= df['Price'] - (0.1 * df['Price'])
DF=pd.DataFrame.to_csv(df, 'df.csv')

# %%
dup = df.drop_duplicates(subset=['EmployeeID'])
dup
# Out:
#   EmployeeID EmployeeName   Age  Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.0   50000   1200      85      90    88.0
# 1       E102          Bob  30.0   60000   1500      78      82    80.0
# 2       E103      Charlie  22.0   52000   1100      92      95    90.0
# 4       E104        David  45.0   80000   2500      88      85    89.0
# 5       E105          Eve  29.0   58000   1300      76      79    81.0
# 6       E106        Frank   NaN    2200     90      91      92    77.0
# 7       E107        Grace  34.0    1900     81      83      80     NaN
# 8       E108        Heidi  38.0    1800     84      86      88     NaN
# 9       E109         Ivan  26.0   53000   1400      95      92    94.0
#
#    Discount_Price
# 0          1080.0
# 1          1350.0
# 2           990.0
# 4          2250.0
# 5          1170.0
# 6            81.0
# 7            72.9
# 8            75.6
# 9          1260.0

# %%
mss = df[['Age','Salary']].isnull().sum() #missing value count korchi
print(mss)
mean_val=df['Age'].mean()
df['Age'].fillna(mean_val,inplace=True)
df
# Out:
# Age       1
# Salary    0
# dtype: int64
# /tmp/ipython-input-2582797090.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(mean_val,inplace=True)
#    EmployeeID EmployeeName   Age  Salary  Price  Marks1  Marks2  Marks3  \
# 0        E101        Alice  25.0   50000   1200      85      90    88.0
# 1        E102          Bob  30.0   60000   1500      78      82    80.0
# 2        E103      Charlie  22.0   52000   1100      92      95    90.0
# ...

# %%
#mean
m1 = df['Marks1'].mean()
m2 = df['Marks2'].mean()
m3 = df['Marks3'].mean()
print(f"Mark1 mean :{m1}, Mark2 mean :{m2}, Mark3 mean :{m3}")
#max
mx1 = df['Marks1'].max()
mx2 = df['Marks2'].max()
mx3 = df['Marks3'].max()

print(f"Mark1 max :{mx1}, Mark2 max :{mx2}, Mark3 max :{mx3}")

print("Total Standard Mark")
to = df['Marks1'] + df['Marks2'] + df['Marks3']
std= to.std()
print(f"deviation of total marks :{std}")
# Out:
# Mark1 mean :85.18181818181819, Mark2 mean :86.81818181818181, Mark3 mean :85.22222222222223
# Mark1 max :95, Mark2 max :95, Mark3 max :94.0
# Total Standard Mark
# deviation of total marks :16.170961628796228

# %%
plt.hist(df['Age'])
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age')
plt.show()

plt.scatter(df['Salary'], df['Price'])
plt.xlabel('Salary')
plt.ylabel('Price')
plt.title('Salary vs Price')
plt.show()

plt.scatter(df['Price'],df['Discount_Price'])
plt.xlabel('Price')
plt.ylabel('Discount_Price')
plt.title('Price vs Discount_Price')
plt.show()

# %%
import numpy as np
import pandas as pd

def generate_students(n=200, seed=42):
    rng = np.random.default_rng(seed)

    hours_studied = rng.normal(5, 2, n).clip(1, 10)
    marks = (hours_studied * rng.uniform(8, 12, n) + rng.normal(0, 5, n)).clip(30, 100)
    gender = rng.choice(['Male', 'Female'], n)
    subject = rng.choice(['Math', 'Science', 'English', 'History'], n)
    study_method = rng.choice(['Solo', 'Group'], n, p=[0.6, 0.4])
    attempts = rng.integers(1, 4, n)

    return pd.DataFrame({
        'hours_studied': hours_studied.round(2),
        'marks': marks.round(2),
        'gender': gender,
        'subject': subject,
        'study_method': study_method,
        'attempts': attempts
    })

def generate_daily_sales(n=60, seed=42):
    rng = np.random.default_rng(seed)

    base = pd.date_range(start='2024-01-01', periods=n, freq='D')
    trend = np.linspace(50, 80, n)
    season = 8 * np.sin(np.linspace(0, 3 * np.pi, n))
    noise = rng.normal(0, 3, n)

    sales = (trend + season + noise).round(2)

    return pd.DataFrame({
        'date': base,
        'sales': sales
    })

# Example usage
students = generate_students(220)
sales = generate_daily_sales(90)

print(students.head())
print(sales.head())
# Out:
#    hours_studied  marks  gender  subject study_method  attempts
# 0           5.61  54.04    Male  English         Solo         2
# 1           2.92  30.00  Female  Science         Solo         2
# 2           6.50  70.46  Female  History        Group         3
# 3           6.88  52.76  Female  English        Group         3
# 4           1.10  30.00  Female  History         Solo         1
#         date  sales
# 0 2024-01-01  50.91
# 1 2024-01-02  48.06
# 2 2024-01-03  54.61
# 3 2024-01-04  56.33
# 4 2024-01-05  48.78

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.lineplot(data=sales, x='date', y='sales',markers='o')
plt.xticks(rotation=45)
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Daily Sales Over Time')
plt.show()

# %%
sns.lineplot(data=students,x='hours_studied',y='marks',hue='gender')
plt.xlabel('Hours_studied')
plt.ylabel('Marks')
plt.title('Hours_studied vs Marks')
plt.show()

# %%
sns.scatterplot(data=students,x='hours_studied',y='marks',hue='subject')
# Out:
# <Axes: xlabel='hours_studied', ylabel='marks'>
